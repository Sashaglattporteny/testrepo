# %% [markdown]
# # Exercs Python Basics I

# %% [markdown]
# ## Exerc. 1
# 1. Write the name of the street of your address
# 2. Write the street number in another
# 3. Population in a third
# 4. Postal code in the fourth variable
# 5. Create a fifth variable that concatenates all of them
# 6. Print it on the screen

# %%
street= "C de Fernandez de los Rios"
st_num= 18
population= 5000
CP= "28015"
adress= street + str(population) + str(st_num) + CP
print(adress)

street= "C de Fernandez de los Rios"
st_num= 18
population= 5000
CP= "28015"
adress= f"{street} {st_num} {population} {CP}"
print(adress)
# Out:
# C de Fernandez de los Rios50001828015
# C de Fernandez de los Rios 18 5000 28015

# %% [markdown]
# ## Exerc. 2
# Replicate the output of exercise two, but this time without using an intermediate variable that concatenates all the others. Perform this exercise on one line, with a single `print`

# %% [markdown]
# ## Exerc. 3
# What variables are misspelled and why? Make your hypothesis first and then run the variables to test it. In that order :)
#
#
# 1. my_variable = "Economy"
# 2. otra_var = "Exercise
# 3. True = "Exercise"
# 4. my variab1e = "Alpha"
# 5. exec = True
# 6. import = 40
# 7. 81mi_variable = "Water"
# 8. my_variable10 = 6

# %% [markdown]
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
# 7.
# 8.

# %% [markdown]
# ## Exerc. 4
# Make a converter from Celsius to Fahrenheit. The converter has to receive the input from the user and return the conversion.
#
# The degree conversion follows the following formula: F = (C × 9 / 5) + 32

# %%
c= float (input("¿A cuántos grados estan?"))
farenheit = (c* 9/5)+32
print(farenheit)
# Out:
# 122.0

# %% [markdown]
# ## Exerc. 5
# Comment Exercise 5 as far as possible. It will be enough to put at least one line comment, and another multiline

# %%
def conversion(c):
    f= (c* 9/5)+32
    return f
c=conversion(50)
print(c)
# Out:
# 122.0

# %%
celcius = int(input("Cual es el clima"))

def conversion(celcius):
    f= (celcius * 9/5)+32
    return f
f = conversion(celcius)
print(f)
# Out:
# 104.0
